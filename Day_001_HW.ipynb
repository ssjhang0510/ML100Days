# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y,yp):
    
    mae = MAE = sum(abs(y-yp))/len(y)
    return mae

def mean_squared_error(y,yp):
    
    mse = MSE = sum((y-yp)**2)
    return mse

# %%
w = 3
b = 0.5
x_lin = np.linspace(0,100,101)
y = (x_lin+np.random.randn(101)*5)*w+b

plt.plot(x_lin, y, 'g.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc=2)
plt.show()

# %%
y_hat = x_lin*w+b
plt.plot(x_lin, y, 'g.', label = 'data')
plt.plot(x_lin, y_hat, 'r.', label = 'prediction')
plt.title("Assume we have data points(And the prediction)")
plt.legend(loc=2)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The mean squared error is %.3f" %(MSE))
print("The mean absolute error is %.3f" %(MAE))
# Out:
# The mean squared error is 24222.996
# The mean absolute error is 12.335

# %%
作業2：
1. 你選的這組資料為何重要

這組資料包含過去預約酒店人群時間、長度等資訊。可供我們預測最佳預定酒店的時間

2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集
## The data is originally from the article Hotel Booking Demand Datasets, written by Nuno Antonio,
## Ana Almeida, and Luis Nunes for Data in Brief, Volume 22, February 2019.
## The data was downloaded and cleaned by Thomas Mock and Antoine Bichat for #TidyTuesday during the week of February 11th,2020.

3. 蒐集而來的資料型態為何
為結構化資料型態，This data set contains a single file which compares various booking information between two hotels:
                 a city hotel and a resort hotel.
           
4. 這組資料想解決的問題如何評估
可利用這組數據建立預測模型以預測未來酒店預訂情形。預測結果對照實際情況即可評估精準度

# %%
作業3:
    
想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)

車隊總載客時數可以相應載客業績，油資為成本。因此若可以分析載客處人口密集的時間分配，精準的分配車隊外出的時間，
便可以達到提升業績效果。

2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)

資料可以從車站附近出入站人數訊息來獲得。

3. 蒐集而來的資料型態為何

結構化資料型態

4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

可實際分配車隊，並從當月業績比對來驗證結果。
